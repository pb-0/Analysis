# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
##import psycopg2
import sqlite3
import re
from functools import partial

#regex funcs
def reg_ex_replace(df):
    return re.sub('[!#?]','',df)

# # replace the matching strings 
# df_updated = df.replace(to_replace ='[nN]ew', value = 'New_', regex = True) 
  
# # Print the updated dataframe 
# print(df_updated) 


# clean_ops = [str.strip, remove_punctuation, str.title]

# def clean_strings(strings, ops):

#     result = []
#     for value in strings:
#         for function in ops:
#             value = function(value)
#         result.append(value)
#     return result

# def apply_to_list(some_list, f):
#     return [f(x) for x in some_list]

# %%
#set csv file
csv_file = 'pr.csv'

# %%
#read in df from csv
df = pd.read_csv(csv_file).drop_duplicates()

# %%
df['id'] = range(1, len(df) + 1)
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       248 non-null    object
#  1   pc_ratio   248 non-null    float64
#  2   price      248 non-null    float64
#  3   pc_change  248 non-null    float64
#  4   pr_change  248 non-null    float64
#  5   id         248 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 11.8+ KB

# %%
df.head(10)
# Out:
#         date  pc_ratio    price  pc_change  pr_change  id
# 0   4-Apr-19      1.45  2879.39   0.004636  -0.068966   1
# 1   5-Apr-19      1.35  2892.74   0.001047   0.007407   2
# 2   8-Apr-19      1.36  2895.77  -0.006067   0.102941   3
# 3   9-Apr-19      1.50  2878.20   0.003478   0.426667   4
# 4  10-Apr-19      2.14  2888.21   0.000038   0.009346   5
# 5  11-Apr-19      2.16  2888.32   0.006609  -0.282407   6
# 6  12-Apr-19      1.55  2907.41  -0.000629   0.077419   7
# 7  15-Apr-19      1.67  2905.58   0.000509   0.263473   8
# 8  16-Apr-19      2.11  2907.06  -0.002274  -0.341232   9
# 9  17-Apr-19      1.39  2900.45   0.001579   0.287770  10

# %%
#pandas df aggs
subscribers_df = df[df['subscribed'] == 1].groupby('metro_area').agg(
    subscribers=pd.NamedAgg(column='subscribed', aggfunc=sum))
subscribers_df['subscriber_share'] = subscribers_df['subscribers']/subscribers_df['subscribers'].sum()
subscribers_df.sort_values(by='subscriber_share', ascending=False)
# Out:
#                                           subscribers  subscriber_share
# metro_area
# DALLAS-FORT WORTH-ARLINGTON                       732          0.074269
# ATLANTA-SANDY SPRINGS-MARIETTA                    692          0.070211
# HOUSTON-SUGAR LAND-BAYTOWN                        516          0.052354
# NEW YORK-NORTHERN NEW JERSEY-LONG ISLAND          456          0.046266
# WASHINGTON-ARLINGTON-ALEXANDRIA                   436          0.044237
# ...                                               ...               ...
# TERRE HAUTE                                         1          0.000101
# GRAND JUNCTION                                      1          0.000101
# GRAND FORKS                                         1          0.000101
# MIDLAND                                             1          0.000101
# ABILENE                                             1          0.000101
#
# [316 rows x 2 columns]

# %%
#pandas df aggs
subscribers_df = df.groupby('metro_area').agg(
    subscriber_rate=pd.NamedAgg(column='subscribed', aggfunc=np.mean),
    subscribers=pd.NamedAgg(column='subscribed', aggfunc=sum)).sort_values('subscribers', ascending=False)

# %%
display(subscribers_df)
# Out:
#                                           subscriber_rate  subscribers
# metro_area
# DALLAS-FORT WORTH-ARLINGTON                      0.256932          732
# ATLANTA-SANDY SPRINGS-MARIETTA                   0.190634          692
# HOUSTON-SUGAR LAND-BAYTOWN                       0.221649          516
# NEW YORK-NORTHERN NEW JERSEY-LONG ISLAND         0.180095          456
# WASHINGTON-ARLINGTON-ALEXANDRIA                  0.244395          436
# ...                                                   ...          ...
# JOHNSTOWN                                        0.000000            0
# JONESBORO                                        0.000000            0
# KINGSPORT-BRISTOL-BRISTOL                        0.000000            0
# KINGSTON                                         0.000000            0
# YUMA                                             0.000000            0
#
# [388 rows x 2 columns]

# %%
#summary stats
df.describe()
# Out:
#                  id    subscribed  services_added  client_bookings  \
# count  45359.000000  45359.000000    45359.000000     45359.000000
# mean   22680.000000      0.217289       20.129170         3.846293
# std    13094.159767      0.412405       21.547604        14.594656
# min        1.000000      0.000000        0.000000         0.000000
# 25%    11340.500000      0.000000        6.000000         0.000000
# 50%    22680.000000      0.000000       13.000000         0.000000
# 75%    34019.500000      0.000000       26.000000         2.000000
# max    45359.000000      1.000000      381.000000       392.000000
#
#        pro_bookings  clients_booked
# count  45359.000000    45359.000000
# mean       3.961838        5.713728
# std       15.625014       15.259606
# min        0.000000        0.000000
# 25%        0.000000        0.000000
# 50%        0.000000        1.000000
# 75%        1.000000        4.000000
# max     1049.000000      361.000000

# %%
#sql operations on pandas. pandas df <-> sql <-> pandas df

conn = sqlite3.connect("Temp.db") 
#df.to_sql('ss', conn, if_exists='replace')

sql_string = '\
SELECT services_decile, sum(subscribed) as subscribers, avg(subscribed) as subscription_rate, count(subscribed) as trialers \
FROM df_buckets \
group by services_decile'
sql_result_1 = pd.read_sql(sql_string, conn)
display(sql_result_3)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: no such table: df_buckets
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-7-99181f4b1550> in <module>
#       8 FROM df_buckets \
#       9 group by services_decile'
# ---> 10 sql_result_1 = pd.read_sql(sql_string, conn)
#      11 display(sql_result_3)
#
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     404
#     405     if isinstance(pandas_sql, SQLiteDatabase):
# --> 406         return pandas_sql.read_query(
#     407             sql,
#     408             index_col=index_col,
#
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT services_decile, sum(subscribed) as subscribers, avg(subscribed) as subscription_rate, count(subscribed) as trialers FROM df_buckets group by services_decile': no such table: df_buckets

# %%
#kde services add

df.to_sql('df', conn, if_exists='replace')

statements = ['drop table if exists df_buckets',
'create table df_buckets as \
Select t1.*, \
ntile(10) over (order by services_added ASC) as services_decile, \
ntile(10) over (order by client_bookings ASC) as bookings_decile, \
ntile(10) over (order by clients_booked ASC) as clients_decile \
from \
df as t1 \
',]


for statement in statements:
    conn.execute(statement)

df_buckets = pd.read_sql('select * from df_buckets', conn)

# %%
# conn.execute('drop table state_data_coded')

# %%
display(df_buckets.sort_values(by=['services_decile'], ascending=False))
# Out:
#        index     id profession_type                                metro_area  \
# 45358  22863  22864    Professional                               SAN ANTONIO
# 42338  28686  28687         Stylist  NEW YORK-NORTHERN NEW JERSEY-LONG ISLAND
# 42332   3911   3912         Stylist                   CLEVELAND-ELYRIA-MENTOR
# 42333  21743  21744   Cosmetologist                          COLORADO SPRINGS
# 42334   5460   5461   Cosmetologist                   SC NONMETROPOLITAN AREA
# ...      ...    ...             ...                                       ...
# 3018   31994  31995         Stylist            ATLANTA-SANDY SPRINGS-MARIETTA
# 3017   31988  31989    Professional                   SEATTLE-TACOMA-BELLEVUE
# 3016   31975  31976    Professional                     GREENSBORO-HIGH POINT
# 3015   31915  31916     Esthetician                         VALLEJO-FAIRFIELD
# 0       1664   1665   Cosmetologist                   PHOENIX-MESA-SCOTTSDALE
#
#       state trial_start_date payment_signup_date  subscribed  services_added  \
# 45358    TX         12/10/18            12/10/18           0             381
# 42338    NJ          11/1/18            12/15/18           1              54
# 42332    OH           9/6/18            10/12/18           1              54
# 42333    CO           1/8/19             2/11/19           1              54
# 42334    SC         12/10/18            12/10/18           1              54
# ...     ...              ...                 ...         ...             ...
# 3018     GA         12/17/18                None           0               2
# 3017     WA          10/4/18                None           0               2
# 3016     NC          6/19/18                None           0               2
# 3015     CA          3/21/19             3/21/19           0               2
# 0        AZ          3/15/18                None           0               0
#
#        client_bookings  ...  clients_booked   week_of  \
# 45358                4  ...               2  12/10/18
# 42338                6  ...              11  10/29/18
# 42332                5  ...              12    9/3/18
# 42333                5  ...              18    1/7/19
# 42334                5  ...              19  12/10/18
# ...                ...  ...             ...       ...
# 3018                 0  ...               0  12/17/18
# 3017                 0  ...               0   10/1/18
# 3016                 0  ...               0   6/18/18
# 3015                 0  ...               0   3/18/19
# 0                    0  ...               0   3/12/18
#
#       services_added_percentile_rank  services_percentile  \
# 45358                            1.0             1.000000
# 42338                            0.9             0.932296
# 42332                            0.9             0.932296
# 42333                            0.9             0.932296
# 42334                            0.9             0.932296
# ...                              ...                  ...
# 3018                             0.0             0.072268
# 3017                             0.0             0.072268
# 3016                             0.0             0.072268
# 3015                             0.0             0.072268
# 0                                0.0             0.015763
#
#        cbookings_percentile  pbookings_percentile  clients_percentile  \
# 45358              0.839150              0.840748            0.659108
# 42338              0.877896              0.859410            0.869982
# 42332              0.860998              0.885183            0.878161
# 42333              0.860998              0.951884            0.912410
# 42334              0.860998              0.937918            0.916709
# ...                     ...                   ...                 ...
# 3018               0.305573              0.323210            0.233724
# 3017               0.305573              0.323210            0.233724
# 3016               0.305573              0.323210            0.233724
# 3015               0.305573              0.323210            0.233724
# 0                  0.305573              0.323210            0.233724
#
#        services_decile  bookings_decile  clients_decile
# 45358               10                9               7
# 42338               10                9               9
# 42332               10                9               9
# 42333               10                9              10
# 42334               10                9              10
# ...                ...              ...             ...
# 3018                 1                2               2
# 3017                 1                2               2
# 3016                 1                2               2
# 3015                 1                2               2
# 0                    1                1               1
#
# [45359 rows x 21 columns]

# %%
#basic scatter
sql_result.plot(kind='bar',x='services_added_percentile_rank',y='subscription_rate',color='blue')

# %%
sql_result_1.plot(kind='bar',x='services_decile',y='subscription_rate',color='blue')

# %%
sql_result_2.plot(kind='bar',x='clients_decile',y='subscription_rate',color='blue')

# %%
sql_result_3.plot(kind='bar',x='bookings_decile',y='subscription_rate',color='blue')

# %%
df.plot(kind='bar',x='services_percentile',y='pro_bookings',color='blue')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/envs/threepointsix/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'services_percentile'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-c90721eb097e> in <module>
# ----> 1 df_buckets.plot(kind='bar',x='services_percentile',y='pro_bookings',color='blue')
#
# /anaconda/envs/threepointsix/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
#     760                     raise ValueError("x must be a label or position")
#     761                 data = data.set_index(x)
#
# /anaconda/envs/threepointsix/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /anaconda/envs/threepointsix/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'services_percentile'

# %%
#statsmodels OLS reg
lin_reg = sm.OLS(df['pc_change'],df['pr_change']).fit()

# %%
import seaborn as sns
sns.regplot(x='pr_change', y='pc_change', data=df)

# %%
print (lin_reg.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              pc_change   R-squared (uncentered):                   0.055
# Model:                            OLS   Adj. R-squared (uncentered):              0.051
# Method:                 Least Squares   F-statistic:                              14.28
# Date:                Sat, 02 May 2020   Prob (F-statistic):                    0.000197
# Time:                        16:49:48   Log-Likelihood:                          322.64
# No. Observations:                 248   AIC:                                     -643.3
# Df Residuals:                     247   BIC:                                     -639.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pr_change      0.0749      0.020      3.779      0.000       0.036       0.114
# ==============================================================================
# Omnibus:                      474.320   Durbin-Watson:                   1.309
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           245168.206
# Skew:                         -11.038   Prob(JB):                         0.00
# Kurtosis:                     155.442   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm

model = sm.OLS(df.subscribed, sm.add_constant(df.services_added))
p = model.fit().params

# x-values for regression line
x = np.arange(1, 80)

ax = df.plot(x='services_added', y='subscribed', kind='scatter')
ax.plot(x, p.const + p.services_added * x)
ax.set_xlim([0, 100])
# Out:
# (0, 100)

# %%
import seaborn as sns
sns.regplot(x='pr_change', y='pc_change', data=df)

# %%
sns.kdeplot(df.clients_booked, df.subscribed)

# %%
sns.lmplot(x="clients_booked", y="subscribed", data=df,
           y_jitter=.1);

# %%
pandas.crosstab()

# %%
kde_violin_df = df
#kde_violin_df['subscribed'] = kde_violin_df['subscribed'].replace(to_replace=0, value=-1)
kde_violin_df['services_percentile'] = kde_violin_df['services_added'].rank(pct=True)
kde_violin_df['cbookings_percentile'] = kde_violin_df['client_bookings'].rank(pct=True)
kde_violin_df['pbookings_percentile'] = kde_violin_df['pro_bookings'].rank(pct=True)
kde_violin_df['clients_percentile'] = kde_violin_df['clients_booked'].rank(pct=True)

# %%
kde_violin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45359 entries, 0 to 45358
# Data columns (total 17 columns):
# id                                45359 non-null int64
# profession_type                   45359 non-null object
# metro_area                        45359 non-null object
# state                             45357 non-null object
# trial_start_date                  45359 non-null object
# payment_signup_date               18493 non-null object
# subscribed                        45359 non-null int64
# services_added                    45359 non-null int64
# client_bookings                   45359 non-null int64
# pro_bookings                      45359 non-null int64
# clients_booked                    45359 non-null int64
# week_of                           45359 non-null object
# services_added_percentile_rank    45359 non-null float64
# services_percentile               45359 non-null float64
# cbookings_percentile              45359 non-null float64
# pbookings_percentile              45359 non-null float64
# clients_percentile                45359 non-null float64
# dtypes: float64(5), int64(6), object(6)
# memory usage: 5.9+ MB

# %% [raw]
# kde_violin_df.head(50)

# %%
sns.violinplot(x="subscribed", y="services_percentile", data=kde_violin_df);

# %%
sns.violinplot(x="subscribed", y="services_percentile", data=kde_violin_df);

# %%
sns.violinplot(x="subscribed", y="pbookings_percentile", data=kde_violin_df);

# %%
sns.violinplot(x="subscribed", y="cbookings_percentile", data=kde_violin_df);

# %%
sns.violinplot(x="subscribed", y="clients_percentile", data=kde_violin_df);

# %%
df.plot(kind='scatter',x='client_bookings',y='services_added',color='red')

# %%
import seaborn as sns
sns.regplot(x='clients_booked', y='subscribed', data=df)

# %%
print (lin_reg.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             subscribed   R-squared (uncentered):                   0.167
# Model:                            OLS   Adj. R-squared (uncentered):              0.167
# Method:                 Least Squares   F-statistic:                              9065.
# Date:                Wed, 20 Nov 2019   Prob (F-statistic):                        0.00
# Time:                        16:35:32   Log-Likelihood:                         -25608.
# No. Observations:               45359   AIC:                                  5.122e+04
# Df Residuals:                   45358   BIC:                                  5.123e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# services_added     0.0065   6.78e-05     95.211      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                     5959.652   Durbin-Watson:                   1.622
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8653.642
# Skew:                           1.065   Prob(JB):                         0.00
# Kurtosis:                       3.209   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
state_encoded.plot(kind='scatter',x='rep_coded',y='openness',color='red')

# %%
state_encoded.plot(kind='scatter',x='dem_coded',y='openness',color='red')

# %%
state_encoded.plot(kind='bar',x='state_code',y='openness',color='red')

# %%
lin_reg = sm.OLS(state_encoded['openness'], state_encoded['rep_coded']).fit()

# %%
print (lin_reg.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               openness   R-squared (uncentered):                   0.602
# Model:                            OLS   Adj. R-squared (uncentered):              0.594
# Method:                 Least Squares   F-statistic:                              71.15
# Date:                Sat, 16 Nov 2019   Prob (F-statistic):                    5.76e-11
# Time:                        21:44:23   Log-Likelihood:                         -234.02
# No. Observations:                  48   AIC:                                      470.0
# Df Residuals:                      47   BIC:                                      471.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rep_coded     47.0485      5.578      8.435      0.000      35.827      58.270
# ==============================================================================
# Omnibus:                       13.563   Durbin-Watson:                   1.102
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                5.796
# Skew:                           0.614   Prob(JB):                       0.0551
# Kurtosis:                       1.821   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
state_encoded.head()
# Out:
#    index       State state_code region    governor               psychRegions  \
# 0      0     Alabama         AL  South  Republican  Friendly and Conventional
# 1      1     Arizona         AZ   West  Republican       Relaxed and Creative
# 2      2    Arkansas         AR  South  Republican  Friendly and Conventional
# 3      3  California         CA   West    Democrat       Relaxed and Creative
# 4      4    Colorado         CO   West    Democrat  Friendly and Conventional
#
#    extraversion  agreeableness  conscientiousness  neuroticism  ...  privacy  \
# 0          55.5           52.7               55.5         48.7  ...     0.58
# 1          50.6           46.6               58.4         38.1  ...    -0.45
# 2          49.9           52.7               41.0         56.2  ...     0.69
# 3          51.4           49.0               43.2         39.1  ...     0.23
# 4          45.3           47.5               58.8         34.3  ...    -0.22
#
#    university  mortgage  volunteering  museum  scrapbook  modernDance  id  \
# 0        1.74      1.41         -1.49   -1.11       0.06        -1.27   1
# 1       -0.77      1.01          0.96   -0.13       0.34         0.41   2
# 2        0.02     -0.66         -1.19   -0.95       0.85        -1.44   3
# 3       -1.92     -0.88          0.57    0.05      -0.69         0.38   4
# 4       -0.44      1.49          1.01    0.72      -0.34        -0.29   5
#
#    rep_coded  dem_coded
# 0          1          0
# 1          1          0
# 2          1          0
# 3          0          1
# 4          0          1
#
# [5 rows x 26 columns]

# %%
#pandas df aggs
state_encoded[state_encoded['rep_coded'] == 1].groupby('psychRegions').agg(
    max_extraversion=pd.NamedAgg(column='extraversion', aggfunc=max),
    min_extraversion=pd.NamedAgg(column='extraversion', aggfunc=min),
    avg_conscientiousness=pd.NamedAgg(column='conscientiousness', aggfunc=np.mean))
# Out:
#                                max_extraversion  min_extraversion  \
# psychRegions
# Friendly and Conventional                  69.8              39.7
# Relaxed and Creative                       55.8              32.4
# Temperamental and Uninhibited              55.2              26.5
#
#                                avg_conscientiousness
# psychRegions
# Friendly and Conventional                     55.535
# Relaxed and Creative                          54.340
# Temperamental and Uninhibited                 39.175

# %%
#reg ex replace
state_encoded['psychRegions'] = state_encoded['psychRegions'].replace(to_replace='Friendly', value='Angry',regex=True)

# %%
display(state_encoded)
# Out:
#     index           State state_code     region    governor  \
# 0       0         Alabama         AL      South  Republican
# 1       1         Arizona         AZ       West  Republican
# 2       2        Arkansas         AR      South  Republican
# 3       3      California         CA       West    Democrat
# 4       4        Colorado         CO       West    Democrat
# 5       5     Connecticut         CT  Northeast    Democrat
# 6       6        Delaware         DE      South    Democrat
# 7       7         Florida         FL      South  Republican
# 8       8         Georgia         GA      South  Republican
# 9       9           Idaho         ID       West  Republican
# 10     10        Illinois         IL    Midwest  Republican
# 11     11         Indiana         IN    Midwest  Republican
# 12     12            Iowa         IA    Midwest  Republican
# 13     13          Kansas         KS    Midwest  Republican
# 14     14        Kentucky         KY      South  Republican
# 15     15       Louisiana         LA      South    Democrat
# 16     16           Maine         ME  Northeast  Republican
# 17     17        Maryland         MD      South  Republican
# 18     18   Massachusetts         MA  Northeast  Republican
# 19     19        Michigan         MI    Midwest  Republican
# 20     20       Minnesota         MN    Midwest    Democrat
# 21     21     Mississippi         MS      South  Republican
# 22     22        Missouri         MO    Midwest  Republican
# 23     23         Montana         MT       West    Democrat
# 24     24        Nebraska         NE    Midwest  Republican
# 25     25          Nevada         NV       West  Republican
# 26     26   New Hampshire         NH  Northeast  Republican
# 27     27      New Jersey         NJ  Northeast    Democrat
# 28     28      New Mexico         NM       West  Republican
# 29     29        New York         NY  Northeast    Democrat
# 30     30  North Carolina         NC      South    Democrat
# 31     31    North Dakota         ND    Midwest  Republican
# 0                55.5         48.7  ...     0.58        1.74      1.41
# 1                58.4         38.1  ...    -0.45       -0.77      1.01
# 2                41.0         56.2  ...     0.69        0.02     -0.66
# 3                43.2         39.1  ...     0.23       -1.92     -0.88
# 4                58.8         34.3  ...    -0.22       -0.44      1.49
# 5                34.2         53.4  ...     0.36        0.37      0.48
# 6                36.5         62.4  ...     0.90        2.19      1.66
# 7                62.7         40.8  ...    -0.14       -1.12      0.11
# 8                68.8         38.0  ...    -0.40       -0.24      0.19
# 9                44.5         44.2  ...     0.08       -0.04      0.64
# 10               50.9         51.2  ...    -0.69        0.31     -0.42
# 11               56.2         59.3  ...     0.44        0.93      0.06
# 12               52.2         49.1  ...    -0.44        1.85     -0.70
# 13               50.8         49.0  ...    -1.02       -0.22     -1.91
# 14               51.3         62.5  ...    -0.35        1.23     -0.71
# 15               45.0         60.4  ...    -1.02       -0.74     -0.11
# 16               24.0         71.0  ...    -0.33       -0.54      0.14
# 17               37.5         49.4  ...     2.87        1.40      1.89
# 18               32.2         63.8  ...     0.49       -0.39      0.51
# 19               53.0         48.6  ...    -0.29        0.60     -0.23
# 20               52.5         43.4  ...    -0.14       -0.10      1.09
# 21               59.7         52.0  ...    -0.79        0.73     -1.15
# 22               60.8         48.3  ...    -0.02        0.41      0.21
# 23               56.1         43.0  ...     0.22        1.14     -0.01
# 24               64.3         41.6  ...    -0.11       -0.52     -0.77
# 25               55.8         44.0  ...    -0.85       -2.36      0.14
# 26               38.0         61.8  ...     0.84       -1.13      1.22
# 27               40.8         56.4  ...     0.30       -0.06      1.00
# 28               58.5         51.6  ...     0.06       -1.21     -0.13
# 29               37.7         62.7  ...    -0.35       -1.13     -0.93
# 30               68.4         44.8  ...     0.56       -0.38      0.85
# 31               51.4         49.6  ...    -0.86       -0.34     -1.21
# 32               46.5         58.5  ...    -0.21        1.89     -0.38
# 33               54.7         52.1  ...     0.01       -0.17      0.41
# 34               45.8         39.5  ...    -2.07       -1.33     -2.59
# 35               52.4         61.4  ...     0.12        0.83      0.10
# 36               48.5         61.9  ...     0.12        0.56      0.86
# 37               69.6         45.7  ...     0.27        0.31      0.33
# 38               55.8         36.1  ...    -0.24        0.81     -0.63
# 39               62.0         49.0  ...     0.08        0.02      0.47
# 40               54.4         44.3  ...    -1.08       -1.19     -1.03
# 41               54.5         30.4  ...    -0.42        0.76      1.80
# 42               38.2         55.8  ...    -0.35       -0.83     -0.99
# 43               45.3         44.7  ...    -0.26       -0.70     -0.73
# 44               45.0         36.9  ...     0.53       -0.24      0.06
# 45               42.6         79.2  ...     0.48        0.92     -2.18
# 46               47.6         48.6  ...    -0.83       -1.01     -0.55
# 47               42.4         46.1  ...    -0.73        0.56     -0.27
#
#     volunteering  museum  scrapbook  modernDance  id  rep_coded  dem_coded
# 0          -1.49   -1.11       0.06        -1.27   1          1          0
# 1           0.96   -0.13       0.34         0.41   2          1          0
# 2          -1.19   -0.95       0.85        -1.44   3          1          0
# 3           0.57    0.05      -0.69         0.38   4          1          1
# 4           1.01    0.72      -0.34        -0.29   5          1          1
# 5           1.28    1.18      -0.81         0.55   6          1          1
# 6           1.37    0.70      -0.73        -0.22   7          1          1
# 7           0.46   -0.74      -0.63        -0.49   8          1          0
# 8          -0.94   -0.75      -0.66        -0.80   9          1          0
# 9          -0.30   -1.42       1.39         0.10  10          1          0
# 10          0.20    0.87      -0.49        -0.46  11          1          0
# 11          0.34    0.12       0.48        -0.32  12          1          0
# 12          0.52   -0.67       0.85        -0.96  13          1          0
# 13         -1.14   -0.80       0.57        -1.09  14          1          0
# 14         -1.29   -0.28       0.42        -0.12  15          1          0
# 15         -1.80   -0.69       0.00         0.00  16          1          1
# 16          0.88    1.17      -0.42         0.45  17          1          0
# 17          1.31    0.94      -0.73         1.93  18          1          0
# 18          1.19    2.21      -1.33         0.73  19          1          0
# 19          0.61   -0.49       0.31        -0.61  20          1          0
# 20          2.11   -0.05       0.34        -0.52  21          1          1
# 21         -1.97   -1.11      -0.18        -0.64  22          1          0
# 22         -0.49    0.14       0.87        -0.97  23          1          0
# 23         -0.59   -0.26       0.50        -0.50  24          1          1
# 24          0.21   -0.26       1.06        -0.98  25          1          0
# 25         -0.55   -0.62      -0.15        -0.02  26          1          0
# 26          0.51    0.91      -0.35         0.29  27          1          0
# 27          1.10    0.48      -0.92         0.75  28          1          1
# 28         -0.79    0.71      -0.80         0.53  29          1          0
# 29          0.38    2.67      -1.50         1.31  30          1          1
# 30          0.51   -0.22      -0.53         0.90  31          1          1
# 31          0.06   -1.48       0.84        -1.22  32          1          0
# 32          0.31    0.08       0.44        -0.42  33          1          0
# 33         -1.35   -0.11       0.68         0.84  34          1          0
# 34         -0.66   -1.43      -1.16        -0.30  35          1          1
# 35          0.63    0.62      -0.52         0.29  36          1          1
# 36          1.05    0.73      -1.06         0.64  37          1          1
# 37         -1.02   -0.93      -0.38        -0.59  38          1          0
# 38         -0.31   -1.11       2.35        -0.97  39          1          0
# 39         -1.05   -0.70       0.06        -0.30  40          1          0
# 40         -0.76   -0.53      -0.28        -0.24  41          1          0
# 41         -0.77   -0.60       4.38         4.70  42          1          0
# 42          0.75    1.73      -0.81         1.63  43          1          0
# 43         -0.10   -0.12      -0.92         0.03  44          1          1
# 44          1.46    0.30      -0.21        -0.10  45          1          1
# 45         -1.48   -1.40       0.23        -0.70  46          1          0
# 46          0.94    0.33       0.84        -0.74  47          1          0
# 47         -1.36   -0.26       0.77         0.46  48          1          0
#
# [48 rows x 26 columns]

# %%
statedata_ts = pd.read_csv('StateData_ts.csv')
#exclude last n columns from df
# .iloc[:,:-2]

# %%
display(statedata_ts)
# Out:
#              State state_code     region    governor  \
# 0          Alabama         AL      South  Republican
# 1          Arizona         AZ       West  Republican
# 2         Arkansas         AR      South  Republican
# 3       California         CA       West    Democrat
# 4         Colorado         CO       West    Democrat
# 5      Connecticut         CT  Northeast    Democrat
# 6         Delaware         DE      South    Democrat
# 7          Florida         FL      South  Republican
# 8          Georgia         GA      South  Republican
# 9            Idaho         ID       West  Republican
# 10        Illinois         IL    Midwest  Republican
# 11         Indiana         IN    Midwest  Republican
# 12            Iowa         IA    Midwest  Republican
# 13          Kansas         KS    Midwest  Republican
# 14        Kentucky         KY      South  Republican
# 15       Louisiana         LA      South    Democrat
# 16           Maine         ME  Northeast  Republican
# 17        Maryland         MD      South  Republican
# 18   Massachusetts         MA  Northeast  Republican
# 19        Michigan         MI    Midwest  Republican
# 20       Minnesota         MN    Midwest    Democrat
# 21     Mississippi         MS      South  Republican
# 22        Missouri         MO    Midwest  Republican
# 23         Montana         MT       West    Democrat
# 24        Nebraska         NE    Midwest  Republican
# 25          Nevada         NV       West  Republican
# 26   New Hampshire         NH  Northeast  Republican
# 27      New Jersey         NJ  Northeast    Democrat
# 28      New Mexico         NM       West  Republican
# 29        New York         NY  Northeast    Democrat
# 30  North Carolina         NC      South    Democrat
# 31    North Dakota         ND    Midwest  Republican
# 32            Ohio         OH    Midwest  Republican
# 33        Oklahoma         OK      South  Republican
# 34          Oregon         OR       West    Democrat
# 35    Pennsylvania         PA  Northeast    Democrat
# 36    Rhode Island         RI  Northeast    Democrat
# 37  South Carolina         SC      South  Republican
# 38    South Dakota         SD    Midwest  Republican
# 39       Tennessee         TN      South  Republican
# 40           Texas         TX      South  Republican
# 41            Utah         UT       West  Republican
# 42         Vermont         VT  Northeast  Republican
# 43        Virginia         VA      South    Democrat
# 44      Washington         WA       West    Democrat
# 45   West Virginia         WV      South  Republican
# 46       Wisconsin         WI    Midwest  Republican
# 47         Wyoming         WY       West  Republican
#
#                      psychRegions  extraversion  agreeableness  \
# 0       Friendly and Conventional          55.5           52.7
# 1            Relaxed and Creative          50.6           46.6
# 2       Friendly and Conventional          49.9           52.7
# 3            Relaxed and Creative          51.4           49.0
# 4       Friendly and Conventional          45.3           47.5
# 5   Temperamental and Uninhibited          57.6           38.6
# 6   Temperamental and Uninhibited          47.0           38.8
# 7       Friendly and Conventional          60.9           50.7
# 8       Friendly and Conventional          63.2           60.0
# 9            Relaxed and Creative          40.7           52.9
# 10      Friendly and Conventional          62.5           48.3
# 11      Friendly and Conventional          48.9           50.2
# 12      Friendly and Conventional          62.8           56.6
# 13      Friendly and Conventional          45.5           48.9
# 14      Friendly and Conventional          53.4           48.1
# 15      Friendly and Conventional          52.2           49.7
# 16  Temperamental and Uninhibited          44.2           32.8
# 17  Temperamental and Uninhibited          35.2           37.3
# 18  Temperamental and Uninhibited          44.4           40.7
# 19      Friendly and Conventional          55.2           54.7
# 20      Friendly and Conventional          52.9           61.6
# 21      Friendly and Conventional          56.8           63.3
# 22      Friendly and Conventional          62.9           59.3
# 23      Friendly and Conventional          33.1           52.3
# 24      Friendly and Conventional          60.0           62.9
# 25           Relaxed and Creative          46.4           31.8
# 26  Temperamental and Uninhibited          40.2           53.5
# 27  Temperamental and Uninhibited          59.9           44.6
# 28           Relaxed and Creative          32.4           45.4
# 29  Temperamental and Uninhibited          47.0           29.8
# 30           Relaxed and Creative          51.0           63.6
# 31      Friendly and Conventional          52.4           52.4
# 32  Temperamental and Uninhibited          54.6           45.9
# 33      Friendly and Conventional          39.7           54.3
# 34           Relaxed and Creative          30.9           59.1
# 35  Temperamental and Uninhibited          54.6           42.8
# 36  Temperamental and Uninhibited          43.3           35.2
# 37      Friendly and Conventional          60.0           55.4
# 38      Friendly and Conventional          58.7           56.7
# 39      Friendly and Conventional          51.3           66.6
# 40  Temperamental and Uninhibited          55.2           52.3
# 41           Relaxed and Creative          55.8           69.4
# 42  Temperamental and Uninhibited          26.5           60.0
# 43           Relaxed and Creative          48.5           47.4
# 44           Relaxed and Creative          30.6           55.8
# 45  Temperamental and Uninhibited          38.5           51.8
# 46      Friendly and Conventional          69.8           57.8
# 47      Friendly and Conventional          46.0           40.7
#
#     conscientiousness  neuroticism  openness  ...  gdpr  privacy  university  \
# 0                55.5         48.7      42.7  ... -0.77     0.58        1.74
# 1                58.4         38.1      54.7  ... -0.31    -0.45       -0.77
# 2                41.0         56.2      40.3  ... -0.60     0.69        0.02
# 3                43.2         39.1      65.0  ...  1.12     0.23       -1.92
# 4                58.8         34.3      57.9  ...  0.59    -0.22       -0.44
# 5                34.2         53.4      53.9  ...  0.71     0.36        0.37
# 6                36.5         62.4      42.7  ...  1.21     0.90        2.19
# 7                62.7         40.8      61.0  ... -0.23    -0.14       -1.12
# 8                68.8         38.0      56.9  ...  0.40    -0.40       -0.24
# 9                44.5         44.2      44.7  ... -0.17     0.08       -0.04
# 10               50.9         51.2      55.2  ...  0.80    -0.69        0.31
# 11               56.2         59.3      44.9  ... -0.46     0.44        0.93
# 12               52.2         49.1      33.7  ... -0.22    -0.44        1.85
# 13               50.8         49.0      40.1  ... -0.25    -1.02       -0.22
# 14               51.3         62.5      43.0  ... -0.75    -0.35        1.23
# 15               45.0         60.4      53.7  ... -1.19    -1.02       -0.74
# 16               24.0         71.0      50.8  ...  0.29    -0.33       -0.54
# 17               37.5         49.4      56.6  ...  0.60     2.87        1.40
# 18               32.2         63.8      59.6  ...  2.24     0.49       -0.39
# 19               53.0         48.6      43.4  ... -0.20    -0.29        0.60
# 20               52.5         43.4      38.5  ...  0.82    -0.14       -0.10
# 21               59.7         52.0      46.2  ... -1.19    -0.79        0.73
# 22               60.8         48.3      45.7  ...  0.34    -0.02        0.41
# 23               56.1         43.0      55.0  ... -1.19     0.22        1.14
# 24               64.3         41.6      34.3  ... -0.37    -0.11       -0.52
# 25               55.8         44.0      61.3  ... -0.07    -0.85       -2.36
# 26               38.0         61.8      48.7  ...  1.46     0.84       -1.13
# 27               40.8         56.4      57.6  ...  1.40     0.30       -0.06
# 28               58.5         51.6      62.0  ... -1.19     0.06       -1.21
# 29               37.7         62.7      64.5  ...  1.29    -0.35       -1.13
# 30               68.4         44.8      49.6  ...  0.07     0.56       -0.38
# 31               51.4         49.6      21.8  ... -1.19    -0.86       -0.34
# Out:
#    month        date day hour
# 0     11  2019-11-17  17   12
# 1     11  2019-11-17  17   12
# 2     11  2019-11-17  17   12
# 3     11  2019-11-17  17   12
# 4     11  2019-11-17  17   12
# 5     11  2019-11-17  17   12
# 6     11  2019-11-17  17   12
# 7     11  2019-11-17  17   12
# 8     11  2019-11-17  17   12
# 9     11  2019-11-17  17   12
# 10    11  2019-11-22  22   12
# 11    11  2019-11-22  22   12
# 12    11  2019-11-22  22   12
# 13    11  2019-11-22  22   12
# 14    11  2019-11-22  22   12
# 15    11  2019-11-22  22   12
# 16    11  2019-11-22  22   12
# 17    11  2019-11-22  22   12
# 18    11  2019-11-22  22   12
# 19    11  2019-11-22  22   12
# 20    11  2019-11-22  22   12
# 21    11  2019-11-22  22   12
# 22    11  2019-11-22  22   12
# 23    11  2019-11-22  22   12
# 24    11  2019-11-22  22   12
# 25    11  2019-11-22  22   12
# 26    11  2019-11-22  22   12
# 27    11  2019-11-25  25   12
# 28    11  2019-11-25  25   12
# 29    11  2019-11-25  25   12
# 30    11  2019-11-25  25   12
# 31    11  2019-11-25  25   12
# 32    11  2019-11-25  25   12
# 33    11  2019-11-25  25   12
# 34    11  2019-11-25  25   12
# 35    11  2019-11-25  25   12
# 36    11  2019-11-25  25   12
# 37    11  2019-11-25  25   12
# 38    11  2019-11-25  25   12
# 39    11  2019-11-25  25   12
# 40    11  2019-11-25  25   12
# 41    11  2019-11-25  25   12
# 42    11  2019-11-25  25   12
# 43    11  2019-11-25  25   12
# 44    11  2019-11-25  25   12
# 45    11  2019-11-25  25   12
# 46    11  2019-11-25  25   12
# 47    11  2019-11-25  25   12

# %%
#sql date diffs, date trunc for time series aggs (sum/avg over week, hour, etc)
#lag and window function in pandas dataframe

# %%
#pandas add column for cumulative sum
statedata_dates_group_by = statedata_dates.groupby(['ts']).cumsum()

# %%
statedata_dates_group_by.head()
# Out:
#    index  extraversion  agreeableness  conscientiousness  neuroticism  \
# 0      0          55.5           52.7               55.5         48.7
# 1      1         106.1           99.3              113.9         86.8
# 2      3         156.0          152.0              154.9        143.0
# 3      6         207.4          201.0              198.1        182.1
# 4     10         252.7          248.5              256.9        216.4
#
#    openness  instagram  facebook  retweet  entrepreneur  gdpr  privacy  \
# 0      42.7       0.64      1.65     0.35          0.26 -0.77     0.58
# 1      97.4       0.82      1.39    -0.22          0.82 -1.08     0.13
# 2     137.7       1.28      2.49    -0.82          1.07 -1.68     0.82
# 3     202.7       2.75      2.07    -0.34          1.57 -0.56     1.05
# 4     260.6       1.71      1.01    -1.24          1.59  0.03     0.83
#
#    university  mortgage  volunteering  museum  scrapbook  modernDance  units
# 0        1.74      1.41         -1.49   -1.11       0.06        -1.27      2
# 1        0.97      2.42         -0.53   -1.24       0.40        -0.86      4
# 2        0.99      1.76         -1.72   -2.19       1.25        -2.30      8
# 3       -0.93      0.88         -1.15   -2.14       0.56        -1.92      9
# 4       -1.37      2.37         -0.14   -1.42       0.22        -2.21     11
